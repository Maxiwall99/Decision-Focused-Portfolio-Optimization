# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print("Hello")
print("Interpreter:", sys.executable)
# Out:
# Hello
# Interpreter: c:\Users\maxiw\master_thesis\.venv\Scripts\python.exe
